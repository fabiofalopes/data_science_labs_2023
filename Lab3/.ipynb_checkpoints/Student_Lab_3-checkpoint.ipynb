# %% [markdown]
# # Practical Lab: Week 3
#
# Note: This practical session is based on the exercises in section 2.4 (Applied) of the module's book.

# %% [markdown]
# ## Part I: The college dataset

# %% [markdown]
# 1. Import `Pandas`
# 2. From the Moodle page (week 3, lab) get the `College.csv` CSV file and put it in the same folder where you saved your Jupyter notebook
# 3. Read the CSV file as a variable called `college`
# 4. Inspect the contents of the dataframe by using the `head()` method from `Pandas`

# %%
import pandas as pd

# %%
college = pd.read_csv("./College.csv")
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %% [markdown]
# 6. Is this a _rectangular_ data structure? If so, What entities are represented in the rows?

# %%
Sim. Linhas entidades e colunas atributos

# %% [markdown]
# The column variables refer to the following information:
#
# - **Private** : Public/private indicator
# - **Apps** : Number of applications received
# - **Accept** : Number of applicants accepted
# - **Enroll** : Number of new students enrolled
# - **Top10perc** : New students from top 10 % of high school class
# - **Top25perc** : New students from top 25 % of high school class
# - **F.Undergrad** : Number of full-time undergraduates
# - **P.Undergrad** : Number of part-time undergraduates
# - **Outstate** : Out-of-state tuition
# - **Room.Board** : Room and board costs
# - **Books** : Estimated book costs
# - **Personal** : Estimated personal spending
# - **PhD** : Percent of faculty with Ph.D.s
# - **bold text**Terminal : Percent of faculty with terminal degree
# - **S.F.Ratio** : Student/faculty ratio
# - **perc.alumni** : Percent of alumni who donate
# - **Expend** : Instructional expenditure per student
# - **Grad.Rate** : Graduation rate

# %% [markdown]
# 7. Use the `describe()` method on the `college` dataframe. Spend some time trying to figure out what information is provided. check the documentation [here.](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)

# %%
college.describe()

# descritivo do df
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# 8. Notice we have the `college` dataframe indexed by column index, and the column with the university names has no name itself, we want to index by the universities. Play with the `Pandas` methods `rename` and `set_index` so that you (a) get rid of the numerical index, (b) make the universities column become the new index, and call that column `College`

# %%
college = college.rename({'Unnamed: 0': 'College'},axis=1) # coluna das universidades deve ser chave primaria 
college = college.set_index('College')
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University           52         2885          537      7440
# Adelphi University                     29         2683         1227     12280
# Adrian College                         50         1036           99     11250
# Agnes Scott College                    89          510           63     12960
# Alaska Pacific University              44          249          869      7560
# ...                                   ...          ...          ...       ...
# Worcester State College                26         3089         2029      6797
# Xavier University                      47         2849         1107     11520
# Xavier University of Louisiana         61         2793          166      6900
# Yale University                        99         5217           83     19840
# York College of Pennsylvania           63         2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# College
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate
# College
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
# [777 rows x 18 columns]

# %% [markdown]
# 9. Use the `pd.plotting.scatter_matrix()` function to produce a scatterplot matrix of the first columns `[Top10perc, Apps, Enroll]`.
#
# For this, you need to slide your dataframe on the three columns. Recall that you can reference a list C of columns of a data frame `A`  using  `A[C]` .

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

df = college[['Top10perc', 'Apps', 'Enroll']]

scatter_matrix(df)

pd.plotting.scatter_matrix(df); # faz uma correlacao em 2 vareaveis

plt.show()

# %% [markdown]
# 10. Use the `boxplot()` method of college to produce side-by-side boxplots of `Outstate` versus `Private`.

# %%
boxplot = college[['Outstate','Private']].boxplot(by='Private')

# %% [markdown]
# 11. Create a new qualitative variable, called `Elite`, by *binning* the `Top10perc` variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
college['Top10perc'].describe()
# Out:
# count    777.000000
# mean      27.558559
# std       17.640364
# min        1.000000
# 25%       15.000000
# 50%       23.000000
# 75%       35.000000
# max       96.000000
# Name: Top10perc, dtype: float64

# %%
#Top10perc is %
college['Elite'] = pd.cut(college['Top10perc'],[0,50,100], # [0,50,100] define 2 intervalos 0-50 e 50-100 e atribui as respetivas labels para cada respetivo intervalo
labels=['No','Yes'])

college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University           52         2885          537      7440
# Adelphi University                     29         2683         1227     12280
# Adrian College                         50         1036           99     11250
# Agnes Scott College                    89          510           63     12960
# Alaska Pacific University              44          249          869      7560
# ...                                   ...          ...          ...       ...
# Worcester State College                26         3089         2029      6797
# Xavier University                      47         2849         1107     11520
# Xavier University of Louisiana         61         2793          166      6900
# Yale University                        99         5217           83     19840
# York College of Pennsylvania           63         2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# College
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# College
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
#                                Elite
# College
# Abilene Christian University      No
# Adelphi University                No
# Adrian College                    No
# Agnes Scott College              Yes
# Alaska Pacific University         No
# ...                              ...
# Worcester State College           No
# Xavier University                 No
# Xavier University of Louisiana    No
# Yale University                  Yes
# York College of Pennsylvania      No
#
# [777 rows x 19 columns]

# %% [markdown]
# Use the `value_counts()` method of college`['Elite']` to see how many elite universities there are. Finally, use the `boxplot()` method again to produce side-by-side boxplots of `Outstate` versus `Elite`.

# %%
print(college['Elite'].value_counts())
boxplot2 = college[['Outstate','Elite']].boxplot(by='Elite')
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %% [markdown]
# 12. Use the `plot.hist()` method of `college` to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
import matplotlib.pyplot as ptl

# create for polar axers and access them through the returned array 
n = 2 
fig, axs = plt.subplots(n,n,figsize=(10,10))

college.Apps.hist(ax=axs[0][0],bins = 1000).set_title('Number of applications')
college.Apps.hist(ax=axs[0][1],bins = 500).set_title('Number of applications')
college.Apps.hist(ax=axs[1][0],bins = 100).set_title('Number of applications')
college.Apps.hist(ax=axs[1][1],bins = 10).set_title('Number of applications')

#bins_list = [[1000,500],[100,10]]

#for x in range(0,n):
#    for y in range(0,n):
#        college.Apps.hist(ax=axs[x][y],bins = bins_list[x][y].set_title('Number of applications'))
# Out:
# Text(0.5, 1.0, 'Number of applications')

# %% [markdown]
# 13. Continue exploring the data, and provide a brief summary of what you discover.

# %% [markdown]
# ## Part II: The Auto dataset

# %% [markdown]
# 1. Import `Pandas`
# 2. From the Moodle page (week 3, lab) get the `Auto.csv` CSV file and put it in the same folder where you saved your Jupyter notebook
# 3. Read the CSV file as a variable called `Auto`
# 4. Inspect the contents of the dataframe by using the `head()` method from `Pandas`

# %%
import pandas as pd
import numpy as np

Auto = pd.read_csv("./Auto.csv")
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1            ford mustang gl
# 393       2                  vw pickup
# 394       1              dodge rampage
# 395       1                ford ranger
# 396       1                 chevy s-10
#
# [397 rows x 9 columns]

# %% [markdown]
# 5. Which of the predictors are quantitative, and which are qualitative?

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
# 6. What is the range of each quantitative predictor? You can answer this using the `min()` and `max()` methods in numpy.

# %%
for pred in Auto:
    print(f"{pred}: min={np.min(Auto[pred])},max={np.max(Auto[pred])}")
# Out:
# mpg: min=9.0,max=46.6
# cylinders: min=3,max=8
# displacement: min=68.0,max=455.0
# horsepower: min=100,max=?
# weight: min=1613,max=5140
# acceleration: min=8.0,max=24.8
# year: min=70,max=82
# origin: min=1,max=3
# name: min=amc ambassador brougham,max=vw rabbit custom

# %%
# horseporwer max ?? vamos inspecionar

for id,x in enumerate(Auto['horsepower']):
    if not x.isnumeric():
        print(id,x)
# Out:
# 32 ?
# 126 ?
# 330 ?
# 336 ?
# 354 ?

# %%
# Exemplo 1 
# Input values

#Aulo.loc[32,'horsepower'] = 100
#Aulo.loc[126,'horsepower'] = 100
#Aulo.loc[330,'horsepower'] = 100
#Aulo.loc[336,'horsepower'] = 100
#Aulo.loc[354,'horsepower'] = 100

# exemplo 2
# drop lines

Auto = Auto.drop([32,126,330,336,354]).reset_index()

# %%
Auto['horsepower'] = Auto['horsepower'].astype(int)

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         392 non-null    int64
#  1   mpg           392 non-null    float64
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    float64
#  4   horsepower    392 non-null    int64
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    float64
#  7   year          392 non-null    int64
#  8   origin        392 non-null    int64
#  9   name          392 non-null    object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 30.8+ KB

# %% [markdown]
# 8. What is the mean and standard deviation of each quantitative predictor?

# %%
for pred in list(Auto)[:-1]:
    #-1 beacuse of "name"
    print(f"{pred}: mean={np.mean(Auto[pred])},std={np.std(Auto[pred])}")
# Out:
# index: mean=197.5204081632653,std=114.29200693317532
# mpg: mean=23.445918367346938,std=7.795045762682584
# cylinders: mean=5.471938775510204,std=1.7036061141501955
# displacement: mean=194.41198979591837,std=104.51044418133284
# horsepower: mean=104.46938775510205,std=38.44203271442593
# weight: mean=2977.5841836734694,std=848.3184465698362
# acceleration: mean=15.541326530612244,std=2.7553429127509967
# year: mean=75.9795918367347,std=3.6790348996151727
# origin: mean=1.5765306122448979,std=0.8044900806593062

# %% [markdown]
# 9. Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
len(Auto)
# Out:
# 392

# %%
Auto = Auto.drop(range(10,86)).reset_index()
Auto
# Out:
#      level_0  index   mpg  cylinders  displacement  horsepower  weight  \
# 0          0      0  18.0          8         307.0         130    3504
# 1          1      1  15.0          8         350.0         165    3693
# 2          2      2  18.0          8         318.0         150    3436
# 3          3      3  16.0          8         304.0         150    3433
# 4          4      4  17.0          8         302.0         140    3449
# ..       ...    ...   ...        ...           ...         ...     ...
# 311      387    392  27.0          4         140.0          86    2790
# 312      388    393  44.0          4          97.0          52    2130
# 313      389    394  32.0          4         135.0          84    2295
# 314      390    395  28.0          4         120.0          79    2625
# 315      391    396  31.0          4         119.0          82    2720
#
#      acceleration  year  origin                       name
# 0            12.0    70       1  chevrolet chevelle malibu
# 1            11.5    70       1          buick skylark 320
# 2            11.0    70       1         plymouth satellite
# 3            12.0    70       1              amc rebel sst
# 4            10.5    70       1                ford torino
# ..            ...   ...     ...                        ...
# 311          15.6    82       1            ford mustang gl
# 312          24.6    82       2                  vw pickup
# 313          11.6    82       1              dodge rampage
# 314          18.6    82       1                ford ranger
# 315          19.4    82       1                 chevy s-10
#
# [316 rows x 11 columns]

# %%
len(Auto)
# Out:
# 316

# %% [markdown]
# 10. Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
import matplotlib.pyplot as plt

plt.scatter(Auto['horsepower'], Auto['year'])
plt.show()

# %% [markdown]
# 11. Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
pd.plotting.scatter_matrix(Auto[['mpg','displacement']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(Auto[['mpg','weight']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(Auto[['mpg','year']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='year'>,
#         <Axes: xlabel='year', ylabel='year'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(Auto[['mpg','acceleration']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='acceleration'>,
#         <Axes: xlabel='acceleration', ylabel='acceleration'>]],
#       dtype=object)

# %% [markdown]
# ## Part III: The Boston dataset

# %% [markdown]
# 1. Import `Pandas`
# 2. From ISLP library get Boston dataset. (Info [link text](https://islp.readthedocs.io/en/latest/datasets/Boston.html))
# 4. Inspect the contents of the dataframe by using the `head()` method from `Pandas`

# %%
# !pip install --force-reinstall -v "numpy==1.22"
# Out:
# Using pip 20.3.4 from /usr/lib/python3/dist-packages/pip (python 3.9)
# User install by explicit request
# Created temporary directory: /tmp/pip-ephem-wheel-cache-ofe3v442
# Created temporary directory: /tmp/pip-req-tracker-_b7m51ft
# Initialized build tracking at /tmp/pip-req-tracker-_b7m51ft
# Created build tracker: /tmp/pip-req-tracker-_b7m51ft
# Entered build tracker: /tmp/pip-req-tracker-_b7m51ft
# Created temporary directory: /tmp/pip-install-31_9_2yv
# 1 location(s) to search for versions of numpy:
# * https://pypi.org/simple/numpy/
# Fetching project page and analyzing links: https://pypi.org/simple/numpy/
# Getting page https://pypi.org/simple/numpy/
# Found index url https://pypi.org/simple
# Getting credentials from keyring for https://pypi.org/simple
# Loading KWallet
# Loading SecretService
# Loading Windows
# Loading chainer
# Loading macOS
# ERROR: Introspect error on :1.632:/modules/kwalletd5: dbus.exceptions.DBusException: org.freedesktop.DBus.Error.NoReply: Message recipient disconnected from message bus without replying
# Executing introspect queue due to error
# WARNING: Keyring is skipped due to an exception: Failed to open keyring: org.freedesktop.DBus.Error.ServiceUnknown: The name :1.632 was not provided by any .service files.
# Looking up "https://pypi.org/simple/numpy/" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/numpy/ HTTP/1.1" 200 210704
# Updating cache with response from "https://pypi.org/simple/numpy/"
# Caching due to etag
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/b7/53/342ee8490dce7939ed31073a1e1d80f114a56bd7b63ebd8d80df79aba5e0/numpy-1.0.1.dev3460.win32-py2.4.exe#sha256=7a1daab190e8584eadc5461d3518cbe0302f6e38143b451f7138c392a4bfc0d8 (from https://pypi.org/simple/numpy/)
#   Found link https://files.pythonhosted.org/packages/ab/67/19e93e3f8c3e077dcf6fc54e84e1cff609c4a7e0a3ce14f70794dde60063/numpy-1.3.0.tar.gz#sha256=7524687cce85aa78103046db5e617c626b0ef871a203a049159f88f35647c90d (from https://pypi.org/simple/numpy/), version: 1.3.0
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/98/b6/d5022159ff85cfb20a063996fe0b5a48199d856a752df20af675001a3fdf/numpy-1.3.0.win32-py2.5.exe#sha256=dadea0e51054a1cce976e143b98de765068e6541f9cd6cdb1819e39c924a5eed (from https://pypi.org/simple/numpy/)
#   Found link https://files.pythonhosted.org/packages/6f/16/84dcacfbabd93ac12c378b823330d8665bdcf8ccea89da17d992afcbcb3a/numpy-1.4.1.tar.gz#sha256=e630d1d7960dd65ca9ed7bcd29c604bb22ef2b28ed6f33574e655a65da1146a6 (from https://pypi.org/simple/numpy/), version: 1.4.1
#   Found link https://files.pythonhosted.org/packages/f4/7e/ee0605be5f922a85f798bf8ff1849d4d043b08229b026e55527110384c6d/numpy-1.5.0.tar.gz#sha256=06d2181c884c5937c7c475103dd55de4fe4842a9d91bab1ed0965dd973a4661a (from https://pypi.org/simple/numpy/), version: 1.5.0
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages
macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=6a20356a4829ff67dbd73c91c763b9cf20aed240f6dd1633cdc9de1bdd86ea6b (from https://pypi.org/simple/numpy/)
#   Skipping link: none of the wheel's tags match: cp33-cp33m-macosx_10_10_intel, cp33-cp33m-macosx_10_10_x86_64, cp33-cp33m-macosx_10_6_intel, cp33-cp33m-macosx_10_9_intel, cp33-cp33m-macosx_10_9_x86_64: https://files.pythonhosted.org/packages/45/44/ec7440a56bf54c52542b3efbf9c975b96a2072c843caea1b762c8269e30e/numpy-1.9.1-cp33-cp33m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=0b07baf08231e1bae5dd4f07cde3996dcabb18f6c5b326936a2e184d142e7afc (from https://pypi.org/simple/numpy/)
#   Skipping link: none of the wheel's tags match: cp33-cp33m-manylinux1_x86_64: https://files.pythonhosted.org/packages/73/de/96a2bb81266dde6c2810cd30c54a312a8288d41199aa23475e0350f3d0bb/numpy-1.9.1-cp33-cp33m-manylinux1_x86_64.whl#sha256=2b1a26b6ea6dbaf755241f7aaf939f246e8ca02fae74b720d3074cc992c6299e (from https://pypi.org/simple/numpy/)
#   Skipping link: none of the wheel's tags match: cp34-cp34m-macosx_10_10_intel, cp34-cp34m-macosx_10_10_x86_64, cp34-cp34m-macosx_10_6_intel, cp34-cp34m-macosx_10_9_intel, cp34-cp34m-macosx_10_9_x86_64: https://files.pythonhosted.org/packages/a0/5d/6e639acac6f6e0a36872d126b512b5e37c855cc1527c2e27bd960508dadc/numpy-1.9.1-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=388958ee6b759d7b1739efef7ac6578e425e28cd783f0da52808debe27547d8b (from https://pypi.org/simple/numpy/)
#   Skipping link: none of the wheel's tags match: cp34-cp34m-manylinux1_x86_64: https://files.pythonhosted.org/packages/0f/6c/66a22a11fada8679e2825b45e0f892a56d8c6f0c4e97a329456079f23f45/numpy-1.9.1-cp34-cp34m-manylinux1_x86_64.whl#sha256=e30fcbe20a9264c849175b581d6300a27666a8ddd48b205245937ca010a63423 (from https://pypi.org/simple/numpy/)
# ...
#   Found link https://files.pythonhosted.org/packages/33/a9/1233954ed69e96e829e6615a6e4a68e8c99d599661edff756fb4300c9a0b/numpy-1.26.0rc1.tar.gz#sha256=49a8cafece27db51fd9ec78c044546b15b0c9bf95466c57ada9eeae64075c2f8 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9), version: 1.26.0rc1
#   Skipping link: none of the wheel's tags match: cp310-cp310-macosx_10_9_x86_64: https://files.pythonhosted.org/packages/be/f8/034752c5131c46e10364e4db241974f2eb6bb31bbfc4335344c19e17d909/numpy-1.26.0-cp310-cp310-macosx_10_9_x86_64.whl#sha256=f8db2f125746e44dce707dd44d4f4efeea8d7e2b43aace3f8d1f235cfa2733dd (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-macosx_11_0_arm64: https://files.pythonhosted.org/packages/5c/ff/0e1f31c70495df6a1afbe98fa237f36e6fb7c5443fcb9a53f43170e5814c/numpy-1.26.0-cp310-cp310-macosx_11_0_arm64.whl#sha256=0621f7daf973d34d18b4e4bafb210bbaf1ef5e0100b5fa750bd9cde84c7ac292 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-manylinux2014_aarch64, cp310-cp310-manylinux_2_17_aarch64: https://files.pythonhosted.org/packages/6a/c7/dc05fb56c0536f499d75ef4e201c37facb75e1ad1f416b98a9939f89f6f1/numpy-1.26.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl#sha256=51be5f8c349fdd1a5568e72713a21f518e7d6707bcf8503b528b88d33b57dc68 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-manylinux2014_x86_64, cp310-cp310-manylinux_2_17_x86_64: https://files.pythonhosted.org/packages/9b/5a/f265a1ba3641d16b5480a217a6aed08cceef09cd173b568cd5351053472a/numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=767254ad364991ccfc4d81b8152912e53e103ec192d1bb4ea6b1f5a7117040be (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-musllinux_1_1_x86_64: https://files.pythonhosted.org/packages/c9/cc/be866f190cfe818e1eb128f887b3cd715cfa554de9d5fe876c5a3ea3af48/numpy-1.26.0-cp310-cp310-musllinux_1_1_x86_64.whl#sha256=436c8e9a4bdeeee84e3e59614d38c3dbd3235838a877af8c211cfcac8a80b8d3 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-win32: https://files.pythonhosted.org/packages/9b/16/bb4ff6c803f3000c130618f75a879fc335c9f9434d1317033c35876709ca/numpy-1.26.0-cp310-cp310-win32.whl#sha256=c2e698cb0c6dda9372ea98a0344245ee65bdc1c9dd939cceed6bb91256837896 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp310-cp310-win_amd64: https://files.pythonhosted.org/packages/cc/05/ef9fc04adda45d537619ea956bc33489f50a46badc949c4280d8309185ec/numpy-1.26.0-cp310-cp310-win_amd64.whl#sha256=09aaee96c2cbdea95de76ecb8a586cb687d281c881f5f17bfc0fb7f5890f6b91 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-macosx_10_9_x86_64: https://files.pythonhosted.org/packages/d2/2f/b42860931c1479714201495ffe47d74460a916ae426a21fc9b68c5e329aa/numpy-1.26.0-cp311-cp311-macosx_10_9_x86_64.whl#sha256=637c58b468a69869258b8ae26f4a4c6ff8abffd4a8334c830ffb63e0feefe99a (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-macosx_11_0_arm64: https://files.pythonhosted.org/packages/35/21/9e150d654da358beb29fe216f339dc17f2b2ac13fff2a89669401a910550/numpy-1.26.0-cp311-cp311-macosx_11_0_arm64.whl#sha256=306545e234503a24fe9ae95ebf84d25cba1fdc27db971aa2d9f1ab6bba19a9dd (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-manylinux2014_aarch64, cp311-cp311-manylinux_2_17_aarch64: https://files.pythonhosted.org/packages/a9/84/baf694be765d68c73f0f8a9d52151c339aed5f2d64205824a6f29021170c/numpy-1.26.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl#sha256=8c6adc33561bd1d46f81131d5352348350fc23df4d742bb246cdfca606ea1208 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-manylinux2014_x86_64, cp311-cp311-manylinux_2_17_x86_64: https://files.pythonhosted.org/packages/c4/36/161e2f8110f8c49e59f6107bd6da4257d30aff9f06373d0471811f73dcc5/numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=e062aa24638bb5018b7841977c360d2f5917268d125c833a686b7cbabbec496c (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-musllinux_1_1_x86_64: https://files.pythonhosted.org/packages/37/41/63975634a93da2a384d3c8084eba467242cab68daab0cd8f4fd470dcee26/numpy-1.26.0-cp311-cp311-musllinux_1_1_x86_64.whl#sha256=546b7dd7e22f3c6861463bebb000646fa730e55df5ee4a0224408b5694cc6148 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-win32: https://files.pythonhosted.org/packages/58/d2/cbc329aa908cb963bd849f14e24f59c002a488e9055fab2c68887a6b5f1c/numpy-1.26.0-cp311-cp311-win32.whl#sha256=c0b45c8b65b79337dee5134d038346d30e109e9e2e9d43464a2970e5c0e93229 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp311-cp311-win_amd64: https://files.pythonhosted.org/packages/93/fd/3f826c6d15d3bdcf65b8031e4835c52b7d9c45add25efa2314b53850e1a2/numpy-1.26.0-cp311-cp311-win_amd64.whl#sha256=eae430ecf5794cb7ae7fa3808740b015aa80747e5266153128ef055975a72b99 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: cp312-cp312-macosx_10_9_x86_64: https://files.pythonhosted.org/packages/e9/83/f8a62f08d38d831a2980427ffc465a4207fe600124b00cfb0ef8265594a7/numpy-1.26.0-cp312-cp312-macosx_10_9_x86_64.whl#sha256=166b36197e9debc4e384e9c652ba60c0bacc216d0fc89e78f973a9760b503388 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: pp39-pypy39_pp73-manylinux2014_x86_64, pp39-pypy39_pp73-manylinux_2_17_x86_64: https://files.pythonhosted.org/packages/08/60/24b68df50a8b513e6de12eeed25028060db6c6abc831eb38178b38e67eb2/numpy-1.26.0-pp39-pypy39_pp73-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=7d484292eaeb3e84a51432a94f53578689ffdea3f90e10c8b203a99be5af57d8 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Skipping link: none of the wheel's tags match: pp39-pypy39_pp73-win_amd64: https://files.pythonhosted.org/packages/25/b6/6dcf9f2a4fc85699dd858c1cdb018d07d490a629f66a38e52bb8b0096cbd/numpy-1.26.0-pp39-pypy39_pp73-win_amd64.whl#sha256=186ba67fad3c60dbe8a3abff3b67a91351100f2661c8e2a80364ae6279720299 (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9)
#   Found link https://files.pythonhosted.org/packages/55/b3/b13bce39ba82b7398c06d10446f5ffd5c07db39b09bd37370dc720c7951c/numpy-1.26.0.tar.gz#sha256=f93fc78fe8bf15afe2b8d6b6499f1c73953169fad1e9a8dd086cdff3190e7fdf (from https://pypi.org/simple/numpy/) (requires-python:<3.13,>=3.9), version: 1.26.0
# Given no hashes to check 2 links for project 'numpy': discarding no candidates
# Collecting numpy==1.22
#   Created temporary directory: /tmp/pip-unpack-g9xg5fjp
#   Looking up "https://files.pythonhosted.org/packages/ec/34/6cf4173a662098da4a71dc219f0facf60cb71202d391c7fe29e92cb519e3/numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl" in the cache
#   No cache entry available
#   Starting new HTTPS connection (1): files.pythonhosted.org:443
#   https://files.pythonhosted.org:443 "GET /packages/ec/34/6cf4173a662098da4a71dc219f0facf60cb71202d391c7fe29e92cb519e3/numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl HTTP/1.1" 200 16829141
#   Downloading numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 8.7 MB/s eta 0:00:01  Ignoring unknown cache-control directive: immutables eta 0:00:02
#   Updating cache with response from "https://files.pythonhosted.org/packages/ec/34/6cf4173a662098da4a71dc219f0facf60cb71202d391c7fe29e92cb519e3/numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl"
#   Caching due to etag
#      |████████████████████████████████| 16.8 MB 8.7 MB/s
#   Added numpy==1.22 from https://files.pythonhosted.org/packages/ec/34/6cf4173a662098da4a71dc219f0facf60cb71202d391c7fe29e92cb519e3/numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=b55b953a1bdb465f4dc181758570d321db4ac23005f90ffd2b434cc6609a63dd to build tracker '/tmp/pip-req-tracker-_b7m51ft'
#   Removed numpy==1.22 from https://files.pythonhosted.org/packages/ec/34/6cf4173a662098da4a71dc219f0facf60cb71202d391c7fe29e92cb519e3/numpy-1.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=b55b953a1bdb465f4dc181758570d321db4ac23005f90ffd2b434cc6609a63dd from build tracker '/tmp/pip-req-tracker-_b7m51ft'
# Created temporary directory: /tmp/pip-unpack-yjqgitr8
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Created temporary directory: /tmp/pip-uninstall-bchwlwum
#       Removing file or directory /home/fabio/.local/bin/f2py
#       Removing file or directory /home/fabio/.local/bin/f2py3
#       Removing file or directory /home/fabio/.local/bin/f2py3.9
#       Created temporary directory: /home/fabio/.local/lib/python3.9/site-packages/~umpy-1.24.1.dist-info
#       Removing file or directory /home/fabio/.local/lib/python3.9/site-packages/numpy-1.24.1.dist-info/
#       Created temporary directory: /home/fabio/.local/lib/python3.9/site-packages/~umpy.libs
#       Removing file or directory /home/fabio/.local/lib/python3.9/site-packages/numpy.libs/
#       Created temporary directory: /home/fabio/.local/lib/python3.9/site-packages/~umpy
#       Removing file or directory /home/fabio/.local/lib/python3.9/site-packages/numpy/
#       Successfully uninstalled numpy-1.24.1
#
#   changing mode of /home/fabio/.local/bin/f2py to 755
#   changing mode of /home/fabio/.local/bin/f2py3 to 755
#   changing mode of /home/fabio/.local/bin/f2py3.9 to 755
# Successfully installed numpy-1.22.0
# Removed build tracker: '/tmp/pip-req-tracker-_b7m51ft'

# %%
# !pip install ISLP
# Out:
# ERROR: Introspect error on :1.636:/modules/kwalletd5: dbus.exceptions.DBusException: org.freedesktop.DBus.Error.NoReply: Message recipient disconnected from message bus without replying
# WARNING: Keyring is skipped due to an exception: Failed to open keyring: org.freedesktop.DBus.Error.ServiceUnknown: The name :1.636 was not provided by any .service files.
# Collecting ISLP
#   Downloading ISLP-0.3.19-py3-none-any.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: lxml in /home/fabio/.local/lib/python3.9/site-packages (from ISLP) (4.9.2)
# Requirement already satisfied: pandas<=1.9,>=0.20 in /home/fabio/.local/lib/python3.9/site-packages (from ISLP) (1.5.3)
# Requirement already satisfied: numpy<1.25,>=1.7.1 in /home/fabio/.local/lib/python3.9/site-packages (from ISLP) (1.22.0)
# Requirement already satisfied: torch in /home/fabio/.local/lib/python3.9/site-packages (from ISLP) (2.0.1)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.9.post0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 3.0 MB/s eta 0:00:01
# Collecting pygam
#   Downloading pygam-0.9.0-py3-none-any.whl (522 kB)
#      |████████████████████████████████| 522 kB 4.6 MB/s eta 0:00:01
# Collecting statsmodels>=0.13
#   Downloading statsmodels-0.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 3.0 MB/s eta 0:00:01    |███████████▋                    | 3.7 MB 5.6 MB/s eta 0:00:02
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.9/dist-packages (from ISLP) (1.10.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from ISLP) (1.2.0)
# Collecting lifelines
#   Downloading lifelines-0.27.8-py3-none-any.whl (350 kB)
#      |████████████████████████████████| 350 kB 5.5 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.9/dist-packages (from ISLP) (1.2.2)
# Collecting torchmetrics
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      |████████████████████████████████| 805 kB 8.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fabio/.local/lib/python3.9/site-packages (from pandas<=1.9,>=0.20->ISLP) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fabio/.local/lib/python3.9/site-packages (from pandas<=1.9,>=0.20->ISLP) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<=1.9,>=0.20->ISLP) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.2->ISLP) (3.1.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=21.3 in /home/fabio/.local/lib/python3.9/site-packages (from statsmodels>=0.13->ISLP) (23.0)
# Collecting formulaic>=0.2.2
#   Downloading formulaic-0.6.5-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.1 MB/s eta 0:00:01
# Collecting autograd>=1.5
#   Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.5 MB/s eta 0:00:011
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.9/dist-packages (from lifelines->ISLP) (3.7.1)
# Collecting autograd-gamma>=0.3
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
# Collecting future>=0.15.2
#   Downloading future-0.18.3.tar.gz (840 kB)
#      |████████████████████████████████| 840 kB 7.1 MB/s eta 0:00:01
# Collecting interface-meta>=1.2.0
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Collecting astor>=0.8
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting wrapt>=1.0
#   Downloading wrapt-1.15.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/fabio/.local/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines->ISLP) (4.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/fabio/.local/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (2.4.7)
# Requirement already satisfied: zipp>=3.1.0 in /home/fabio/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->lifelines->ISLP) (3.15.0)
# Collecting numpy<1.25,>=1.7.1
#   Downloading numpy-1.24.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 379 kB/s eta 0:00:01    |████▍                           | 2.4 MB 6.8 MB/s eta 0:00:03     |███████████████████████         | 12.5 MB 4.9 MB/s eta 0:00:01
# Collecting progressbar2<5.0.0,>=4.2.0
#   Downloading progressbar2-4.2.0-py2.py3-none-any.whl (27 kB)
# Collecting python-utils>=3.0.0
#   Downloading python_utils-3.8.1-py2.py3-none-any.whl (27 kB)
# Collecting fsspec[http]>2021.06.0
#   Downloading fsspec-2023.9.2-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.57.0 in /home/fabio/.local/lib/python3.9/site-packages (from pytorch-lightning->ISLP) (4.64.1)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      |████████████████████████████████| 738 kB 7.9 MB/s eta 0:00:01
# Collecting lightning-utilities>=0.7.0
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.25.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/fabio/.local/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.8.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/fabio/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.7.99)
# Requirement already satisfied: networkx in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (3.1)
# Requirement already satisfied: jinja2 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (3.1.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.7.99)
# Requirement already satisfied: filelock in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (3.12.0)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.7.91)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (10.2.10.91)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.7.4.91)
# Requirement already satisfied: sympy in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (1.12)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (10.9.0.58)
# Requirement already satisfied: triton==2.0.0 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (2.0.0)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (2.14.3)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (8.5.0.96)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.4.0.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/fabio/.local/lib/python3.9/site-packages (from torch->ISLP) (11.7.101)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->ISLP) (0.34.2)
# Requirement already satisfied: setuptools in /home/fabio/.local/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->ISLP) (67.7.2)
# Requirement already satisfied: lit in /home/fabio/.local/lib/python3.9/site-packages (from triton==2.0.0->torch->ISLP) (16.0.5)
# Requirement already satisfied: cmake in /home/fabio/.local/lib/python3.9/site-packages (from triton==2.0.0->torch->ISLP) (3.26.3)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabio/.local/lib/python3.9/site-packages (from jinja2->torch->ISLP) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/fabio/.local/lib/python3.9/site-packages (from sympy->torch->ISLP) (1.3.0)
# Building wheels for collected packages: autograd-gamma, future
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4032 sha256=3e335fb99722c6e368aa2a9262b713ce6ccbdc52a3745c9c3e670985ee6edc75
#   Stored in directory: /home/fabio/.cache/pip/wheels/a8/03/64/8557323821d25118c3a2dc1646996f7a962a8970d4b7d22473
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492025 sha256=3f74252df4f80f71250c82900db2353fb766bb978d917dfc562a195c1d43addb
#   Stored in directory: /home/fabio/.cache/pip/wheels/bf/5d/6a/2e53874f7ec4e2bede522385439531fafec8fafe005b5c3d1b
# Successfully built autograd-gamma future
# Installing collected packages: numpy, future, wrapt, python-utils, lightning-utilities, interface-meta, fsspec, autograd, astor, torchmetrics, PyYAML, progressbar2, patsy, formulaic, autograd-gamma, statsmodels, pytorch-lightning, pygam, lifelines, ISLP
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
#       Successfully uninstalled numpy-1.22.0
# Successfully installed ISLP-0.3.19 PyYAML-6.0.1 astor-0.8.1 autograd-1.6.2 autograd-gamma-0.5.0 formulaic-0.6.5 fsspec-2023.9.2 future-0.18.3 interface-meta-1.3.0 lifelines-0.27.8 lightning-utilities-0.9.0 numpy-1.24.4 patsy-0.5.3 progressbar2-4.2.0 pygam-0.9.0 python-utils-3.8.1 pytorch-lightning-2.0.9.post0 statsmodels-0.14.0 torchmetrics-1.2.0 wrapt-1.15.0

# %%
from ISLP import load_data
import numpy as np

Boston = load_data('Boston')
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# 3       18.7   2.94  33.4
# 4       18.7   5.33  36.2
# ..       ...    ...   ...
# 501     21.0   9.67  22.4
# 502     21.0   9.08  20.6
# 503     21.0   5.64  23.9
# 504     21.0   6.48  22.0
# 505     21.0   7.88  11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# 1. How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
len(Boston) # rows
# Out:
# 506

# %%
len(Boston.columns) # columns
# Out:
# 13

# %%
list(Boston)
# Out:
# ['crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'lstat',
#  'medv']

# %% [markdown]
# 4. Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %% [markdown]
# 5. Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %% [markdown]
# 6. Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %% [markdown]
# 7. How many of the suburbs in this data set bound the Charles river?

# %% [markdown]
# 8. What is the median pupil-teacher ratio among the towns in this data set?

# %% [markdown]
# 9. Which suburb of Boston has lowest median value of owner- occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %% [markdown]
# 10. In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.
